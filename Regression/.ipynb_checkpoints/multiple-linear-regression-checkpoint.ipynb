# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('regression-dataset.csv')

data
# Out:
#      age  experience_years  education_years  hours_per_week     salary
# 0     58                35               13              34  112093.47
# 1     48                30               10              41  118193.18
# 2     34                16               13              45  112136.67
# 3     27                 9               10              55   84545.83
# 4     40                20               14              55  109400.73
# ..   ...               ...              ...             ...        ...
# 145   49                30               15              50  137953.13
# 146   30                 7               18              34   75641.40
# 147   47                27               14              32  110232.36
# 148   44                22               10              41  116329.26
# 149   58                40               13              54  170316.37
#
# [150 rows x 5 columns]

# %%
X = data[['experience_years']]
y = data['salary']

model = LinearRegression()
model.fit(X, y)

y_pred = model.predict(X)

print(f"Intercept: {model.intercept_:.2f}")
print(f"Slope: {model.coef_[0]:.2f}")

mse = mean_squared_error(y, y_pred)
rmse = np.sqrt(mse)

print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print("R2 Score:", r2_score(y, y_pred))
# Out:
# Intercept: 63747.46
# Slope: 2014.30
# MSE: 166475120.04
# RMSE: 12902.52
# R2 Score: 0.7673451752332274

# %% [markdown]
# <h1>Multiple Linear Regression</h1>

# %%
X = data[['age', 'experience_years', 'education_years', 'hours_per_week']]
y = data['salary']

model = LinearRegression()
model.fit(X, y)

y_pred = model.predict(X)

print(f"Intercept: {model.intercept_:.2f}")

for feature, coef in zip(X.columns, model.coef_):
    print(f"{feature}: {coef:.2f}")

mse = mean_squared_error(y, y_pred)
rmse = np.sqrt(mse)

scaler = StandardScaler()

print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print("R2 Score:", r2_score(y, y_pred))

new_person = [[30, 8, 15, 30]]
prediction = model.predict(new_person)

print("Prediction:", prediction[0])
print("Prediction", new_person)
# Out:
# Intercept: 6337.90
# age: 332.92
# experience_years: 1656.67
# education_years: 1444.89
# hours_per_week: 679.17
# MSE: 110743462.02
# RMSE: 10523.47
# R2 Score: 0.8452321239042903
# Prediction: 71627.04519891817
# Prediction [[30, 8, 15, 30]]
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
