# %% [markdown]
# <h1>Basic Problems</h1>

# %%
import math

# %% [markdown]
# <h3>1 . Write a program to show greeting message along with a user's name and age</h3>

# %%
name = "Rohit"

# %%
age = 21

# %%
print(f"Hello {name}, your age is {age}.")
# Out:
# Hello Rohit, your age is 21.

# %% [markdown]
# <h3>2 . Write a program to compute the square of a user-input number </h3>

# %%
num1 = int(input("Enter the number"))
# Out:
# Enter the number 5

# %%
square_no = num1 * num1

# %%
print(f"Square of {num1} is {square_no}")
# Out:
# Square of 5 is 25

# %% [markdown]
# <h3>3 . Write a program to declare variables for a student's name, roll number, and marks in three subjects, then calculate and display the total marks</h3>

# %%
student_name = "Gopal"
roll_no = 12

# Subjects
maths = 75
bio = 65
hindi = 89

# %%
total_marks = maths + bio + hindi

# %%
print(f"Total marks : {total_marks}")
# Out:
# Total marks : 229

# %% [markdown]
# <h3>4 . Write a program to accept a string, calculate its length, and extract the first three characters and last three characters using slicing</h3>

# %%
long_str = input("Enter any long string")
# Out:
# Enter any long string hellothisisfrom

# %%
print(f"Length of given string {len(long_str)}")
# Out:
# Length of given string 15

# %%
first_three = long_str[:4]

# %%
print(f"First three {first_three}")
# Out:
# First three hell

# %%
last_three = long_str[-3:]

# %%
print(f"Last three {last_three}")
# Out:
# Last three rom

# %% [markdown]
# <h3>5 . Write a program to display a formatted message using escape sequences like newline, tab, and quotes.</h3>

# %%
print(f"His address is \nCity \t Ranchi")
# Out:
# His address is
# City 	 Ranchi

# %% [markdown]
# <h3>6 . Write a program to display a bill with item name, quantity, and price using f-strings and the format() method</h3>

# %%
item_name = "Pen"
quantity = 10
price = 10
total_price = price * quantity

# %%
print("Bill \nItem Name \t{}\nQuantity \t{}\nPrice \t{}\nTotal Price \t{}".format(item_name,quantity,price,total_price))
# Out:
# Bill
# Item Name 	Pen
# Quantity 	10
# Price 	10
# Total Price 	100

# %%
print(f"Bill \nItem Name \t{item_name}\nQuantity \t{quantity}\nPrice \t{price}\nTotal Price \t{total_price}")
# Out:
# Bill
# Item Name 	Pen
# Quantity 	10
# Price 	10
# Total Price 	100

# %% [markdown]
# <h3>7 . Write a program to take a string input and apply methods like upper(), lower(), strip(), and replace/h3>

# %%
some_str = input("Enter any string")
# Out:
# Enter any string hi

# %%
print(f"In Uppercase \t{some_str.upper()}\nIn Lowercase \t{some_str.lower()}\nStrip \t{some_str.strip()}\nReplace \t{some_str.replace(some_str[0], "Replaced")}")
# Out:
# In Uppercase 	HI
# In Lowercase 	hi
# Strip 	hi
# Replace 	Replacedi

# %% [markdown]
# <h3>8 . Write a program to perform addition, subtraction, multiplication, division, amd modulus on two user-input numbers.</h3>

# %%
number1 = int(input("Enter the first number"))
# Out:
# Enter the first number 10

# %%
number2 = int(input("Enter the second number"))
# Out:
# Enter the second number 20

# %%
addition = number1 + number2
subtraction = number1 - number2
multiplication = number1 * number2
division = number1 / number2
modulus = number1 % number2

# %%
print(f"Calculation of the given two numbers : {number1}, {number2} \nAddition \t{addition} \nSubraction \t{subtraction} \nMultiplication \t{multiplication} \nDivision \t{division} \nModulus \t{modulus}")
# Out:
# Calculation of the given two numbers : 10, 20
# Addition 	30
# Subraction 	-10
# Multiplication 	200
# Division 	0.5
# Modulus 	10

# %% [markdown]
# <h3>9 . Write a program to compute the absolute value, power, and square root of a number using math module functions</h3>

# %%
some_value = 29.5

# %%
# Absolute
print(f"Absolute values {math.fabs(some_value)}")
# Out:
# Absolute values 29.5

# %%
# Power
print(f"Power {math.pow(some_value, 2)}")
# Out:
# Power 870.25

# %%
# Square root
print(f"Square root {math.sqrt(some_value)}")
# Out:
# Square root 5.431390245600108

# %% [markdown]
# <h3>10 . Write a program to accept a user's name and age, then display a formatted message with the input values</h3>

# %%
username = input("Enter your name")
user_age = int(input("Enter your age"))
# Out:
# Enter your name Jai
# Enter your age 33

# %%
print(f"My name is {username} and my age is {age}")
# Out:
# My name is Jai and my age is 21

# %% [markdown]
# <h3>11 . Write a program to convert a string to an integer and a float to a string, then display the results</h3>

# %%
str_num = input("Enter any number")
# Out:
# Enter any number 3

# %%
print(type(str_num))
# Out:
# <class 'str'>

# %%
to_int = int(str_num)
print(type(to_int))
# Out:
# <class 'int'>

# %%
float_num = 13.5
to_str = str(float_num)

# %%
print(f"{type(float_num)} \n{type(to_str)}")
# Out:
# <class 'float'>
# <class 'str'>

# %% [markdown]
# <h3>12 . Write a program to compare two numbers using comparision operators and display whether they are equal, greater, or less than each other</h3>

# %%
compare_num1 = 99
compare_num2 = 65

# %%
if compare_num1 == compare_num2:
    print("Both are equal")

elif compare_num1 > compare_num2:
    print(f"{compare_num1} is greater than {compare_num2}")
else:
    print(f"{compare_num1} is less than {compare_num2}")
# Out:
# 99 is greater than 65
