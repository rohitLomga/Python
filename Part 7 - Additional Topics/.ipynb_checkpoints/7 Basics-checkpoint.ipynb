# %% [markdown]
# <h1>Additional Topics ( Part 7)</h1>

# %% [markdown]
# <h3>1</h3>

# %%
name = input("Enter name: ")
print(f"Welcome {name}")
# Out:
# Enter name:  skdjf
# Welcome skdjf

# %% [markdown]
# <h3>2</h3>

# %%
age = int(input("Enter age: "))
print(f"Your age is {age}")
# Out:
# Enter age:  78
# Your age is 78

# %% [markdown]
# <h3>3</h3>

# %%
a = int(input())
b = int(input())
print(f"Sum = {a+b}")
# Out:
#  44
#  44
# Sum = 88

# %% [markdown]
# <h3>4</h3>

# %%
name = input()
roll = input()

print(f"Student: {name}, Roll: {roll}")
# Out:
#  salkd
#  77
# Student: salkd, Roll: 77

# %% [markdown]
# <h3>5</h3>

# %%
marks = float(input())
print(f"{marks:.2f}")
# Out:
#  558
# 558.00

# %% [markdown]
# <h3>6</h3>

# %%
city = input()
print(f"Welcome to {city}")
# Out:
#  dkfj
# Welcome to dkfj

# %% [markdown]
# <h3>7</h3>

# %%
l = float(input())
b = float(input())

print(f"Area = {l*b}")
# Out:
#  23
#  3
# Area = 69.0

# %% [markdown]
# <h3>8</h3>

# %%
color = input()
print(f"Your favorite color is {color}")
# Out:
#  dflmk
# Your favorite color is dflmk

# %% [markdown]
# <h3>9</h3>

# %%
name = input()
course = input()

print(f"{name} studies {course}")
# Out:
#  Rohit
#  CSE
# Rohit studies CSE

# %% [markdown]
# <h3>10</h3>

# %%
c = float(input())

f = (c*9/5)+32

print(f"{f:.2f}")
# Out:
#  44
# 111.20

# %% [markdown]
# <h3>11</h3>

# %%
price = float(input())
qty = int(input())

print(f"Total = {price*qty}")
# Out:
#  58
#  87
# Total = 5046.0

# %% [markdown]
# <h3>12</h3>

# %%
p = float(input())
r = float(input())
t = float(input())

si = (p*r*t)/100

print(f"SI = {si}")
# Out:
#  14
#  14
#  14
# SI = 27.44

# %% [markdown]
# <h3>13</h3>

# %%
name = input()
city = input()
pin = input()

print(f"{name}\n{city}\n{pin}")
# Out:
#  yu
#  you
#  hi
# yu
# you
# hi

# %% [markdown]
# <h3></h3>

# %% [markdown]
# <h3></h3>
