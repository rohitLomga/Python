# %% [markdown]
# <h1>Basic Problems (Exception Handling)</h1>

# %% [markdown]
# <h3>1 .</h3>

# %%
from datetime import datetime, timedelta, date
import math

# %%
now = datetime.now()
print("Current Date and Time:", now)
# Out:
# Current Date and Time: 2026-03-09 19:02:52.813833

# %% [markdown]
# <h3>2 . </h3>

# %%
today = date.today()
print("Current Date:", today)
# Out:
# Current Date: 2026-03-09

# %% [markdown]
# <h3>3 .</h3>

# %%
time = datetime.now().time()
print("Current Time:", time)
# Out:
# Current Time: 19:02:52.890936

# %% [markdown]
# <h3>4 .</h3>

# %%
today = datetime.now()
print(today.strftime("%d-%m-%Y"))
# Out:
# 09-03-2026

# %% [markdown]
# <h3>5 .</h3>

# %%
d1 = datetime(2024,5,1)
d2 = datetime(2024,5,10)

print("Difference:", (d2-d1).days, "days")
# Out:
# Difference: 9 days

# %% [markdown]
# <h3>6 . </h3>

# %%
today = datetime.now()
new_date = today + timedelta(days=7)

print(new_date)
# Out:
# 2026-03-16 19:02:53.092587

# %% [markdown]
# <h3>7 .</h3>

# %%
num = int(input("Enter number: "))
print("Square root:", math.sqrt(num))
# Out:
# Enter number:  47
# Square root: 6.855654600401044

# %% [markdown]
# <h3>8 .</h3>

# %%
import random

print(random.randint(1,10))
# Out:
# 7

# %% [markdown]
# <h3>9 .</h3>

# %%
print(datetime.now())
# Out:
# 2026-03-09 19:05:10.454548

# %% [markdown]
# <h3>10 .</h3>

# %%
import sys

print(sys.version)
# Out:
# 3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 16:37:03) [MSC v.1929 64 bit (AMD64)]

# %% [markdown]
# <h3>11 .</h3>

# %%
import mymodule

mymodule.greet()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 import mymodule
#       3 mymodule.greet()
#
# ModuleNotFoundError: No module named 'mymodule'
